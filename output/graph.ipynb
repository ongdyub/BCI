# %%
import os
import pickle

os.getcwd()
with open(file="./gru-base/record_cer.pkl", mode="rb") as f:
    gru = pickle.load(f)

with open(file="./rnn-base/record_cer.pkl", mode="rb") as f:
    gru_bi = pickle.load(f)

with open(file="./lstm-base/record_cer.pkl", mode="rb") as f:
    gru_4 = pickle.load(f)

# %%
with open(file="./lstm-base/record_cer.pkl", mode="rb") as f:
    gru = pickle.load(f)

with open(file="./lstm-bi/record_cer.pkl", mode="rb") as f:
    gru_bi = pickle.load(f)

with open(file="./lstm-deep/record_cer.pkl", mode="rb") as f:
    gru_4 = pickle.load(f)

# %%
import matplotlib.pyplot as plt
print(len(gru))
print(gru_4[200])
# 그래프 그리기
plt.plot(gru, label="Loss 1", color="red")
plt.plot(gru_bi, label="Loss 2", color="blue")
plt.plot(gru_4, label="Loss 3", color="green")

# 그래프 제목과 범례 추가
plt.title("Loss Curves")
plt.legend()

# x축 및 y축 레이블 추가
plt.xlabel("Epochs")
plt.ylabel("Loss")

# 그래프 표시
plt.show()
# Out:
# 201
# 0.25882600906312575
